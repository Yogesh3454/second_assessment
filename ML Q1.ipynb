# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("instagram_reach.csv")

# %%
data
# Out:
#     Unnamed: 0  S.No              USERNAME  \
# 0            0     1         mikequindazzi
# 1            1     2       drgorillapaints
# 2            2     3    aitrading_official
# 3            3     4  opensourcedworkplace
# 4            4     5           crea.vision
# ..         ...   ...                   ...
# 95           8    19        michaelgarza__
# 96           9    21           dvlp_search
# 97          10    22            ecom.space
# 98          11    24        lb3enterprises
# 99          12    25          palmariusdev
#
#                                               Caption  Followers  \
# 0   Who are #DataScientist and what do they do? >>...       1600
# 1   We all know where it’s going. We just have to ...        880
# 2   Alexander Barinov: 4 years as CFO in multinati...        255
# 3                                                sfad        340
# 4   Ever missed a call while your phone was chargi...        304
# ...

# %%
data.head()
# Out:
#    Unnamed: 0  S.No              USERNAME  \
# 0           0     1         mikequindazzi
# 1           1     2       drgorillapaints
# 2           2     3    aitrading_official
# 3           3     4  opensourcedworkplace
# 4           4     5           crea.vision
#
#                                              Caption  Followers  \
# 0  Who are #DataScientist and what do they do? >>...       1600
# 1  We all know where it’s going. We just have to ...        880
# 2  Alexander Barinov: 4 years as CFO in multinati...        255
# 3                                               sfad        340
# 4  Ever missed a call while your phone was chargi...        304
#
#                                             Hashtags Time since posted  Likes
# 0  #MachineLearning #AI #DataAnalytics #DataScien...          11 hours    139
# 1   #deck .#mac #macintosh#sayhello #apple #steve...           2 hours     23
# 2  #whoiswho #aitrading #ai #aitradingteam#instat...           2 hours     25
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0        S.No   Followers      Likes
# count  100.000000  100.000000   100.00000  100.00000
# mean     8.940000   16.240000   961.96000   46.48000
# std      6.639064    7.384286  1014.62567   55.08698
# min      0.000000    1.000000    11.00000    8.00000
# 25%      4.000000   10.750000   252.75000   19.00000
# 50%      8.000000   16.500000   612.00000   29.00000
# 75%     12.250000   22.250000  1197.00000   46.00000
# max     26.000000   30.000000  4496.00000  349.00000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         100 non-null    int64
#  1   S.No               100 non-null    int64
#  2   USERNAME           100 non-null    object
#  3   Caption            94 non-null     object
#  4   Followers          100 non-null    int64
#  5   Hashtags           100 non-null    object
#  6   Time since posted  100 non-null    object
#  7   Likes              100 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
data.shape
# Out:
# (100, 8)

# %%
data.isnull()
# Out:
#     Unnamed: 0   S.No  USERNAME  Caption  Followers  Hashtags  \
# 0        False  False     False    False      False     False
# 1        False  False     False    False      False     False
# 2        False  False     False    False      False     False
# 3        False  False     False    False      False     False
# 4        False  False     False    False      False     False
# ..         ...    ...       ...      ...        ...       ...
# 95       False  False     False    False      False     False
# 96       False  False     False    False      False     False
# 97       False  False     False    False      False     False
# 98       False  False     False    False      False     False
# 99       False  False     False    False      False     False
#
#     Time since posted  Likes
# 0               False  False
# 1               False  False
# 2               False  False
# 3               False  False
# 4               False  False
# ..                ...    ...
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# S.No                 0
# USERNAME             0
# Caption              6
# Followers            0
# Hashtags             0
# Time since posted    0
# Likes                0
# dtype: int64

# %%
# Handle missing values
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (94, 8)

# %%
# Encode categorical features
data = pd.get_dummies(data, columns=['USERNAME', 'Caption', 'Hashtags'], drop_first=True)

# %%
# Encode categorical features
data = pd.get_dummies(data, columns=['Time since posted'], drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[95], line 2
#       1 # Encode categorical features
# ----> 2 data = pd.get_dummies(data, columns=['Time since posted'], drop_first=True)
#
# File C:\anaconda\Lib\site-packages\pandas\core\reshape\encoding.py:158, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     156     raise TypeError("Input must be a list-like for parameter `columns`")
#     157 else:
# --> 158     data_to_encode = data[columns]
#     160 # validate prefixes and separator to avoid silently dropping cols
#     161 def check_len(item, name):
#
# File C:\anaconda\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Scale numerical features
scaler = StandardScaler()
data[['Followers']] = scaler.fit_transform(data[['Followers']])

# %%
X = data.drop(['Likes', 'Time since posted'], axis=1)

# %%
y_likes = data['Likes']

# %%
y_time_since_posted = data['Time since posted']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train_likes, y_test_likes, y_train_time, y_test_time = train_test_split(X, y_likes, y_time_since_posted, 
                                                                                           test_size=0.2, random_state=42)

# %%
X_train
# Out:
#     Unnamed: 0  S.No  Followers  USERNAME__linda_smith567  \
# 66           4    16  -0.777299                     False
# 15          15    20   0.027859                     False
# 70           8    23   0.252714                     False
# 82           9    17  -0.095861                     False
# 30           3    11  -0.112553                     False
# ..         ...   ...        ...                       ...
# 61          22    30  -0.914765                     False
# 74           1     6  -0.198960                     False
# 14          14    18   1.925871                     False
# 98          11    24   1.076527                     False
# 51          12    20   1.310220                     False
#
#     USERNAME_ah_studio_  USERNAME_aitrading_official  USERNAME_ale_borba  \
# 66                False                        False               False
# 15                False                        False               False
# ...

# %%
y_train_likes
# Out:
# 66     31
# 15     53
# 70     21
# 82     31
# 30     90
#      ...
# 61     10
# 74     35
# 14     28
# 98    222
# 51    157
# Name: Likes, Length: 75, dtype: int64

# %%
y_train_time
# Out:
# 66    2 hours
# 15    3 hours
# 70    2 hours
# 82    2 hours
# 30    2 hours
#        ...
# 61    3 hours
# 74    2 hours
# 14    3 hours
# 98    3 hours
# 51    4 hours
# Name: Time since posted, Length: 75, dtype: object

# %%
# Encode categorical features
data = pd.get_dummies(data, columns=['Time since posted'], drop_first=True)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Model for predicting likes
model_likes = RandomForestRegressor()

# %%
model_likes.fit(X_train, y_train_likes)
# Out:
# RandomForestRegressor()

# %%
# Model for predicting time since posted
model_time = RandomForestRegressor()

# %%
model_time.fit(X_train, y_train_time)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 model_time.fit(X_train, y_train_time)
#
# File C:\anaconda\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File C:\anaconda\Lib\site-packages\sklearn\ensemble\_forest.py:393, in BaseForest.fit(self, X, y, sample_weight)
#     390 y, expanded_class_weight = self._validate_y_class_weight(y)
#     392 if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
# --> 393     y = np.ascontiguousarray(y, dtype=DOUBLE)
# ...
